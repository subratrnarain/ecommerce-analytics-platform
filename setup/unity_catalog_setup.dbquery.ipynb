-- %%
-- Use the workspace catalog
USE CATALOG workspace;

-- Ensure the schema exists (Phase 1 confirmation)
CREATE SCHEMA IF NOT EXISTS dev_bronze_layer;

-- Create the Managed Volume referenced in your ingestion code
CREATE VOLUME IF NOT EXISTS dev_bronze_layer.raw_files
COMMENT 'Managed volume for landing raw ecommerce CSV data';

-- Verify the volume is now visible
SHOW VOLUMES IN dev_bronze_layer;

CREATE SCHEMA IF NOT EXISTS dev_silver_layer 
COMMENT 'Silver layer for cleaned and deduplicated behavior data';

CREATE SCHEMA IF NOT EXISTS dev_gold_layer 
COMMENT 'Gold layer for aggregated business KPIs';
