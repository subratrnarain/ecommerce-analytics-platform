-- %%
-- Final Integration Verification Script
SELECT 
    (SELECT COUNT(*) FROM workspace.dev_bronze_layer.events_raw) as bronze_count,
    (SELECT COUNT(*) FROM workspace.dev_silver_layer.events_cleaned) as silver_count,
    (SELECT COUNT(*) FROM workspace.dev_gold_layer.product_performance) as gold_count;
-- Validation: bronze_count >= silver_count (due to DQ drops)
