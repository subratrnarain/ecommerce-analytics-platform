# %%
# Create a directory for the raw files 
dbutils.fs.mkdirs("/Volumes/workspace/default/ecommerce_analytics_dev/bronze_layer/raw_files")

# %%
# %sh
# Downloading 67M+ record dataset directly
curl -L -o /tmp/ecommerce_data.zip https://www.kaggle.com/api/v1/datasets/download/mkechinov/ecommerce-behavior-data-from-multi-category-store

# Unzip directly into working Volume path 
unzip /tmp/ecommerce_data.zip -d /Volumes/workspace/default/ecommerce_analytics_dev/bronze_layer/raw_files/
